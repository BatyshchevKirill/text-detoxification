# %% [markdown]
# # To be deleted

# %%
# !git clone https://BatyshchevKirill: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@github.com/BatyshchevKirill/text-detoxification.git
# Out:
# Cloning into 'text-detoxification'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 68 (delta 18), reused 51 (delta 14), pack-reused 5
# Receiving objects: 100% (68/68), 42.45 MiB | 26.57 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
import os
os.chdir('/content/text-detoxification')

# %%
# !pip install contractions

# %% [markdown]
# Data preprocessing

# %%
import src.data.preprocess as p

p.unpack('/content/text-detoxification/data/raw/filtered_paranmt.zip', '/content/text-detoxification/data/raw')

# %%
df = p.read('/content/text-detoxification/data/raw/filtered.tsv')
df.head()
# Out:
#    similarity  lenght_diff                                              toxic  \
# 0    0.785171     0.010309  if Alkar floods her with her mental waste, it ...
# 1    0.749687     0.071429                        you're becoming disgusting.
# 2    0.919051     0.268293                      well, we can spare your life.
# 3    0.664333     0.309524                       monkey, you have to wake up.
# 4    0.726639     0.181818                         I have orders to kill her.
#
#                                              detoxed   tox_lvl   dtx_lvl
# 0  If Alkar is flooding her with psychic waste, t...  0.981983  0.014195
# 1                          Now you're getting nasty.  0.999039  0.065473
# 2           Well, we could spare your life, for one.  0.985068  0.213313
# 3          Ah! Monkey, you've got to snap out of it.  0.994215  0.053362
# 4                   I've got orders to put her down.  0.999348  0.009402

# %%
df = p.filter_df(df)
df['len'] = df.toxic.str.len()
df.describe()
# Out:
#           similarity    lenght_diff        tox_lvl        dtx_lvl  \
# count  363842.000000  363842.000000  363842.000000  363842.000000
# mean        0.747018       0.163977       0.982229       0.004593
# std         0.090303       0.109745       0.022816       0.007238
# min         0.600001       0.000000       0.900002       0.000033
# 25%         0.671395       0.071429       0.973920       0.000087
# 50%         0.739904       0.149123       0.992881       0.000667
# 75%         0.815322       0.250000       0.998581       0.006106
# max         0.950000       0.400000       0.999730       0.029999
#
#                  len
# count  363842.000000
# mean       49.918951
# std        32.001192
# min         2.000000
# 25%        27.000000
# 50%        41.000000
# 75%        64.000000
# max       199.000000

# %%
df = p.lower(df)
df
# Out:
#         similarity  lenght_diff  \
# 0         0.785171     0.010309
# 4         0.726639     0.181818
# 6         0.618866     0.230769
# 10        0.800661     0.160000
# 13        0.660481     0.270270
# ...            ...          ...
# 577770    0.934512     0.171429
# 577772    0.870322     0.030769
# 577774    0.617511     0.212121
# 577775    0.679613     0.358209
# 577776    0.868475     0.095238
#
#                                                     toxic  \
# 0       if alkar floods her with her mental waste, it ...
# 4                              i have orders to kill her.
# 6       they're all laughing at us, so we'll kick your...
# 10      you'd probably want me to buy you some chocola...
# 13                   come on, cal, leave that shit alone.
# ...                                                   ...
# 577770                 i am so crazy nuts about you guys.
# 577772  you didn't know that estelle stole your fish f...
# ...

# %%
df = p.filter_english(df)
df
# Out:
#         similarity  lenght_diff  \
# 0         0.785171     0.010309
# 1         0.726639     0.181818
# 2         0.618866     0.230769
# 3         0.800661     0.160000
# 4         0.660481     0.270270
# ...            ...          ...
# 338642    0.934512     0.171429
# 338643    0.870322     0.030769
# 338644    0.617511     0.212121
# 338645    0.679613     0.358209
# 338646    0.868475     0.095238
#
#                                                     toxic  \
# 0       if alkar floods her with her mental waste, it ...
# 1                              i have orders to kill her.
# 2       they're all laughing at us, so we'll kick your...
# 3       you'd probably want me to buy you some chocola...
# 4                    come on, cal, leave that shit alone.
# ...                                                   ...
# 338642                 i am so crazy nuts about you guys.
# 338643  you didn't know that estelle stole your fish f...
# ...

# %%
# df = p.expand_contractions(df)
df["toxic"] = df["toxic"].str.replace("in'", "ing")
df
# Out:
#         similarity  lenght_diff  \
# 0         0.785171     0.010309
# 1         0.726639     0.181818
# 2         0.618866     0.230769
# 3         0.800661     0.160000
# 4         0.660481     0.270270
# ...            ...          ...
# 338642    0.934512     0.171429
# 338643    0.870322     0.030769
# 338644    0.617511     0.212121
# 338645    0.679613     0.358209
# 338646    0.868475     0.095238
#
#                                                     toxic  \
# 0       if alkar floods her with her mental waste, it ...
# 1                              i have orders to kill her.
# 2       they're all laughing at us, so we'll kick your...
# 3       you'd probably want me to buy you some chocola...
# 4                    come on, cal, leave that shit alone.
# ...                                                   ...
# 338642                 i am so crazy nuts about you guys.
# 338643  you didn't know that estelle stole your fish f...
# ...

# %%
from nltk.tag.hmm import unique_list
from tqdm import tqdm
import nltk
nltk.download('punkt')

full_text = df['toxic'].tolist() + df['detoxed'].tolist()

unique_words = dict()
progress = tqdm(full_text)
for text in progress:
    splitted_words = nltk.tokenize.word_tokenize(text.lower())
    for word in splitted_words:
        if word in unique_words:
            unique_words[word] += 1
        else:
            unique_words[word] = 1
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 100%|██████████| 677294/677294 [01:42<00:00, 6616.77it/s]

# %%
print(f"Unique words in text:{len(unique_words)}")
unique_words = [ (unique_words[k], k) for k in unique_words]
unique_words.sort(reverse=True)
print(len(unique_words))
print(unique_words[:100])
# Out:
# Unique words in text:83752
# 83752
# ...

# %%
import re
from collections import Counter


toxic_texts = df['toxic'].str.lower().tolist()
detoxified_texts = df['detoxed'].str.lower().tolist()

toxic_words = re.split(r'[ \t\n,;.!?"\'()-]', ' '.join(toxic_texts))
detoxified_words = re.split(r'[ \t\n,;.!?"\'()-]', ' '.join(detoxified_texts))

toxic_word_counts = Counter(toxic_words)
detoxified_word_counts = Counter(detoxified_words)

word_diff = {}
for word, count in toxic_word_counts.items():
    if word in detoxified_word_counts:
        detoxified_count = detoxified_word_counts[word]
        if count > 2 * detoxified_count:
            word_diff[word] = count - detoxified_count

sorted_word_diff = sorted(word_diff.items(), key=lambda x: x[1], reverse=True)

top_words = sorted_word_diff[:1000]
for word, diff in top_words:
    print(f'Word: {word}, Frequency Difference: {diff}')
# Out:
# Word: fucking, Frequency Difference: 28704
# Word: shit, Frequency Difference: 27024
# Word: fuck, Frequency Difference: 16596
# Word: damn, Frequency Difference: 15130
# Word: ass, Frequency Difference: 8556
# Word: kill, Frequency Difference: 7124
# Word: shut, Frequency Difference: 6291
# Word: stupid, Frequency Difference: 6033
# Word: sex, Frequency Difference: 4069
# Word: crap, Frequency Difference: 3718
# Word: bitch, Frequency Difference: 3669
# Word: shoot, Frequency Difference: 3558
# Word: fool, Frequency Difference: 3360
# Word: ridiculous, Frequency Difference: 2985
# Word: die, Frequency Difference: 2932
# Word: balls, Frequency Difference: 2496
# Word: useless, Frequency Difference: 2402
# Word: dick, Frequency Difference: 2289
# Word: pussy, Frequency Difference: 2013
# Word: bastard, Frequency Difference: 1912
# Word: pathetic, Frequency Difference: 1830
# Word: suck, Frequency Difference: 1827
# Word: loser, Frequency Difference: 1789
# ...
